# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Project 1 — Meridian Insurance Co. (Titanic passenger data)

# %%
titanic_dataset = pd.read_csv('Dataset/Titanic-Dataset.csv',index_col='PassengerId')

# %% [markdown]
# ### 1. Load the dataset and display the first 8 rows and the last 5 rows.

# %%
titanic_dataset.head(8)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# ...

# %%
titanic_dataset.tail(5)
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ### 2.Print the shape, column names, and dtype of every column.

# %%
# shape
shape = titanic_dataset.shape
print(f'Total column : {shape[0]} \n Total row : {shape[1]}')
# Out:
# Total column : 891
#  Total row : 11

# %%
# Column names
column_names = titanic_dataset.columns.tolist()
print(f'The name of all column are : {column_names}')
# Out:
# The name of all column are : ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
#dtype
dtype = titanic_dataset.dtypes
print(f'The datatype of each column is : \n{dtype}')
# Out:
# The datatype of each column is :
# Survived      int64
# Pclass        int64
# Name            str
# Sex             str
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket          str
# Fare        float64
# Cabin           str
# Embarked        str
# dtype: object

# %% [markdown]
# ### 3.Use .info() and .describe() to summarize the dataset; note in a comment which columns have missing values and how many.

# %%
titanic_dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    str
#  3   Sex       891 non-null    str
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    str
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    str
#  10  Embarked  889 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 76.7 KB

# %%
titanic_dataset.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### 4. Select only Name, Sex, Age, and Survived into a new DataFrame.

# %% [markdown]
# ###

# %%
new_titanic_df = titanic_dataset[['Name','Sex','Age','Survived']]
new_titanic_df.set_index('Name',inplace=True)

# %%
new_titanic_df
# Out:
#                                                        Sex   Age  Survived
# Name
# Braund, Mr. Owen Harris                               male  22.0         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0         1
# Heikkinen, Miss. Laina                              female  26.0         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        female  35.0         1
# Allen, Mr. William Henry                              male  35.0         0
# ...                                                    ...   ...       ...
# Montvila, Rev. Juozas                                 male  27.0         0
# Graham, Miss. Margaret Edith                        female  19.0         1
# Johnston, Miss. Catherine Helen "Carrie"            female   NaN         0
# Behr, Mr. Karl Howell                                 male  26.0         1
# Dooley, Mr. Patrick                                   male  32.0         0
#
# [891 rows x 3 columns]

# %% [markdown]
# ###

# %% [markdown]
# ### 5. Using .loc, get all passengers older than 60. Using .iloc, get rows 100 through 110.

# %%
titanic_dataset.loc[titanic_dataset['Age']>60].head(5)
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 34                  0       2           Wheadon, Mr. Edward H  male  66.0
# 55                  0       1  Ostby, Mr. Engelhart Cornelius  male  65.0
# 97                  0       1       Goldschmidt, Mr. George B  male  71.0
# 117                 0       3            Connors, Mr. Patrick  male  70.5
# 171                 0       1       Van der hoef, Mr. Wyckoff  male  61.0
#
#              SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# 34               0      0  C.A. 24579  10.5000   NaN        S
# 55               0      1      113509  61.9792   B30        C
# 97               0      0    PC 17754  34.6542    A5        C
# 117              0      0      370369   7.7500   NaN        Q
# 171              0      0      111240  33.5000   B19        S

# %%
titanic_dataset.iloc[99:110]
# Out:
#              Survived  Pclass                              Name     Sex   Age  \
# PassengerId
# 100                 0       2                 Kantor, Mr. Sinai    male  34.0
# 101                 0       3           Petranec, Miss. Matilda  female  28.0
# 102                 0       3  Petroff, Mr. Pastcho ("Pentcho")    male   NaN
# 103                 0       1         White, Mr. Richard Frasar    male  21.0
# 104                 0       3        Johansson, Mr. Gustaf Joel    male  33.0
# 105                 0       3    Gustafsson, Mr. Anders Vilhelm    male  37.0
# 106                 0       3             Mionoff, Mr. Stoytcho    male  28.0
# 107                 1       3  Salkjelsvik, Miss. Anna Kristine  female  21.0
# 108                 1       3            Moss, Mr. Albert Johan    male   NaN
# 109                 0       3                   Rekic, Mr. Tido    male  38.0
# 110                 1       3               Moran, Miss. Bertha  female   NaN
#
# ...

# %% [markdown]
# ### 6. Filter to show only female, 1st-class passengers who survived.

# %%
female_only = titanic_dataset.groupby('Sex').get_group('female')

# %%
female_only.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name            str
# Sex             str
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket          str
# Fare        float64
# Cabin           str
# Embarked        str
# dtype: object

# %%
final_answer = female_only[(female_only['Pclass'] == 1) & (female_only['Survived'] == 1)]

# %%
final_answer.sample(5)
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 195                 1       1  Brown, Mrs. James Joseph (Margaret Tobin)
# 888                 1       1               Graham, Miss. Margaret Edith
# 196                 1       1                       Lurette, Miss. Elise
# 89                  1       1                 Fortune, Miss. Mabel Helen
# 311                 1       1             Hays, Miss. Margaret Bechstein
#
#                 Sex   Age  SibSp  Parch    Ticket      Fare        Cabin  \
# PassengerId
# 195          female  44.0      0      0  PC 17610   27.7208           B4
# 888          female  19.0      0      0    112053   30.0000          B42
# 196          female  58.0      0      0  PC 17569  146.5208          B80
# 89           female  23.0      3      2     19950  263.0000  C23 C25 C27
# 311          female  24.0      0      0     11767   83.1583          C54
#
#             Embarked
# PassengerId
# 195                C
# ...

# %% [markdown]
# ### 7. Count how many passengers embarked from each port (Embarked) with value_counts(), including missing values in the count.

# %%
titanic_dataset['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
titanic_dataset['Embarked'].isnull().sum()
# Out:
# np.int64(2)

# %% [markdown]
# ### 8. Fill missing Age with the median age, fill missing Embarked with the most frequent port, and drop the Cabin column entirely (it's mostly missing).

# %%
titanic_dataset.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
titanic_dataset = titanic_dataset.drop(columns=['Cabin'])

# %%
titanic_dataset['Age'] = titanic_dataset['Age'].fillna(titanic_dataset['Age'].mean())
titanic_dataset['Embarked'] = titanic_dataset['Embarked'].fillna(titanic_dataset['Embarked'].mode()[0])

# %%
titanic_dataset.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
titanic_dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 1 to 891
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    str
#  3   Sex       891 non-null    str
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    str
#  8   Fare      891 non-null    float64
#  9   Embarked  891 non-null    str
# dtypes: float64(2), int64(4), str(4)
# memory usage: 69.7 KB

# %% [markdown]
# ### 9. Create an AgeGroup column that bins Age into Child (0–12), Teen (13–19), Adult (20–59), Senior (60+) using pd.cut().

# %%
bins = [-1,12,19,59,float('inf')]

labels = ['Child','Teen','Adult','Senior']

titanic_dataset['AgeGroup'] = pd.cut(titanic_dataset['Age'],bins=bins,labels=labels)

# %%
titanic_dataset.sample(5)
# Out:
#              Survived  Pclass                                         Name  \
# PassengerId
# 449                 1       3               Baclini, Miss. Marie Catherine
# 392                 1       3                       Jansson, Mr. Carl Olof
# 574                 1       3                            Kelly, Miss. Mary
# 727                 1       2  Renouf, Mrs. Peter Henry (Lillian Jefferys)
# 830                 1       1    Stone, Mrs. George Nelson (Martha Evelyn)
#
#                 Sex        Age  SibSp  Parch  Ticket     Fare Embarked  \
# PassengerId
# 449          female   5.000000      2      1    2666  19.2583        C
# 392            male  21.000000      0      0  350034   7.7958        S
# 574          female  29.699118      0      0   14312   7.7500        Q
# 727          female  30.000000      3      0   31027  21.0000        S
# 830          female  62.000000      0      0  113572  80.0000        S
#
#             AgeGroup
# PassengerId
# 449            Child
# ...

# %% [markdown]
# ### 10. Sort by Fare descending and show the top 10 highest-paying passengers.

# %%
titanic_dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    str
#  3   Sex       891 non-null    str
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    str
#  8   Fare      891 non-null    float64
#  9   Embarked  891 non-null    str
#  10  AgeGroup  891 non-null    category
# dtypes: category(1), float64(2), int64(4), str(4)
# memory usage: 70.8 KB

# %%
titanic_dataset.sort_values('Fare',ascending=False,inplace=True)

# %% [markdown]
# ### 11. Group by Pclass and Sex together and calculate the mean survival rate for each combination.

# %%
test = titanic_dataset.groupby(['Pclass','Sex'])
test['Survived'].mean()
# Out:
# Pclass  Sex
# 1       female    0.968085
#         male      0.368852
# 2       female    0.921053
#         male      0.157407
# 3       female    0.500000
#         male      0.135447
# Name: Survived, dtype: float64

# %%
test.groups
# Out:
# {(1,
#   'female'): Index([259,  89, 342, 743, 312, 300, 701, 717, 381, 780, 731, 690, 319, 857,
#         269, 610, 709, 298, 499, 196,  32, 326, 270, 320, 338, 335, 764, 436,
#         394, 216, 582, 307, 308, 538, 821, 521, 292, 487, 413, 850, 760, 258,
#         505, 231, 836, 880, 311, 376, 830,  62, 586, 559, 257, 291, 592, 497,
#         276, 628, 766,  53, 219, 367,   2, 541, 642, 370, 152, 514, 330, 524,
#         782, 310, 578, 357, 167, 810,   4, 872, 670, 384, 458, 572, 711, 540,
#         557, 854, 843, 888, 178, 195,  12, 137, 863, 797],
#        dtype='int64', name='PassengerId'),
#  (1,
#   'male'): Index([680, 738, 439,  28, 119, 558, 528, 378, 333, 306,
#         ...
#         546, 285, 169, 663, 873, 634, 264, 807, 816, 823],
#        dtype='int64', name='PassengerId', length=122),
#  (2,
#   'female'): Index([755, 616,  44, 609, 671, 619, 721, 597, 417,  10, 581, 324, 473,  59,
#         601, 802, 441, 238, 536, 531,  54, 428, 507, 881, 260, 547, 855, 427,
# ...

# %%
for name, group in test:
    print(f"Group: {name}")
    print(group.head(2)) # Prints the first 2 rows of each group
    print("-" * 30)
# Out:
# Group: (1, 'female')
#              Survived  Pclass                        Name     Sex   Age  \
# PassengerId
# 259                 1       1            Ward, Miss. Anna  female  35.0
# 89                  1       1  Fortune, Miss. Mabel Helen  female  23.0
#
#              SibSp  Parch    Ticket      Fare Embarked AgeGroup
# PassengerId
# 259              0      0  PC 17755  512.3292        C    Adult
# 89               3      2     19950  263.0000        S    Adult
# ------------------------------
# Group: (1, 'male')
#              Survived  Pclass                                Name   Sex   Age  \
# PassengerId
# 680                 1       1  Cardeza, Mr. Thomas Drake Martinez  male  36.0
# 738                 1       1              Lesurer, Mr. Gustave J  male  35.0
#
#              SibSp  Parch    Ticket      Fare Embarked AgeGroup
# PassengerId
# 680              0      1  PC 17755  512.3292        C    Adult
# ...

# %% [markdown]
# ### 12. Export the cleaned dataset to cleaned_titanic.csv without the index column.

# %%
titanic_dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 891 entries, 680 to 823
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    str
#  3   Sex       891 non-null    str
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    str
#  8   Fare      891 non-null    float64
#  9   Embarked  891 non-null    str
#  10  AgeGroup  891 non-null    category
# dtypes: category(1), float64(2), int64(4), str(4)
# memory usage: 77.6 KB

# %%
final_df = titanic_dataset.copy()

# %%
final_df.to_csv(path_or_buf='/media/leo/Disk_D/My Future/Project/Python_Libraries/Pandas/Dataset/clean_titanic_dataset.csv')
